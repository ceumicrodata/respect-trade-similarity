# %%
import glob
import pandas as pd

# %%
file_list = glob.glob('input/trade_input_dwl/data/*')
for file_name in file_list:
    data = pd.read_csv(file_name)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5a5eb7ac20db> in <module>()
#       1 file_list = glob.glob('input/trade_input_dwl/data/*')
#       2 for file_name in file_list:
# ----> 3     data = pd.read_csv(file_name)
#
# ...

# %%
file_list = glob.glob('input/trade_input_dwl/data/*')
file_list
# Out:
# ['input/trade_input_dwl/data/full200152.dat',
#  'input/trade_input_dwl/data/full200552.dat',
#  'input/trade_input_dwl/data/full200352.dat',
#  'input/trade_input_dwl/data/full200752.dat',
#  'input/trade_input_dwl/data/full201252.dat',
#  'input/trade_input_dwl/data/full201852.dat',
#  'input/trade_input_dwl/data/full201152.dat',
#  'input/trade_input_dwl/data/full200252.dat',
#  'input/trade_input_dwl/data/full201352.dat',
#  'input/trade_input_dwl/data/full201452.dat',
#  'input/trade_input_dwl/data/full200852.dat',
#  'input/trade_input_dwl/data/full200452.dat',
#  'input/trade_input_dwl/data/full201652.dat',
#  'input/trade_input_dwl/data/full201752.dat',
#  'input/trade_input_dwl/data/full201052.dat',
#  'input/trade_input_dwl/data/full201552.dat',
#  'input/trade_input_dwl/data/full200952.dat',
#  'input/trade_input_dwl/data/full200652.dat']

# %%
data.head()

# %%
file_list

# %%
file_list = glob.glob('input/trade_input_dwl/data/full200152.dat')
file_list
# Out:
# ['input/trade_input_dwl/data/full200152.dat']

# %%
pd.read_csv('input/trade_input_dwl/data/full200152.dat')
# Out:
#          DECLARANT DECLARANT_ISO  PARTNER PARTNER_ISO TRADE_TYPE PRODUCT_NC  \
# 0                1            FR        3          NL          I   01011100
# 1                1            FR        3          NL          I   01011910
# 2                1            FR        3          NL          I   01011990
# 3                1            FR        3          NL          I   01011990
# 4                1            FR        3          NL          I   01012090
# 5                1            FR        3          NL          I   01021010
# 6                1            FR        3          NL          I   01021030
# 7                1            FR        3          NL          I   01021090
# 8                1            FR        3          NL          I   01021090
# 9                1            FR        3          NL          I   01029005
# 10               1            FR        3          NL          I   01029005
# ...
